# %%
import pandas as pd
import numpy as np

# import data: csv -> pandas df
df = pd.read_csv('spotify_global_2019_most_streamed_tracks_audio_features.csv')

# %%
# attributes for all data
df.columns
# Out:
# Index(['Country', 'Rank', 'Track_id', 'Streams', 'Track Name', 'Artist', 'URL',
#        'acousticness', 'danceability', 'energy', 'instrumentalness',
#        'liveness', 'loudness', 'speechiness', 'valence', 'tempo',
#        'time_signature', 'duration_ms', 'key', 'mode', 'Artist_id',
#        'Artist_popularity', 'Artist_follower', 'Artist_img'],
#       dtype='object')

# %%
# table of song-artist data
df.head(10)
# Out:
#   Country  Rank                Track_id     Streams         Track Name  \
# 0  global   1.0  25sgk305KZfyuqVBQIahim  1166185736   Sweet but Psycho
# 1  global   2.0  2Fxmhks0bxGSBdJ92vM42m  1052358787            bad guy
# 2  global   3.0  6ocbgoVGwYJhOv1GgI9NsF   789094044            7 rings
# 3  global   4.0  1rgnBhdG2JDFTbYkYRZAku   764208309       Dance Monkey
# 4  global   5.0  6v3KW9xbzN5yKLt9YKDYA2   763064359           Señorita
# 5  global   6.0  5w9c2J52mkdntKOmRLeM2m   715027898          Con Calma
# 6  global   7.0  2VxeLyX666F8uXCJ0dZF8B   714097238            Shallow
# 7  global   8.0  7qEHsqek33rTcFNT9PFqLf   661930419  Someone You Loved
# 8  global   9.0  2dpaYNEQHiRxtZbfNsse99   620829467            Happier
# 9  global  10.0  6MWtB6iiXyIwun0YzU6DFP   615519053               Wow.
#
#           Artist                                                URL  \
# 0        Ava Max  https://open.spotify.com/track/25sgk305KZfyuqV...
# ...

# %%
# table of artist data with given attributes
artistsDB = df[['Artist','Artist_popularity','Artist_follower','Artist_id']]
artistsDB.head(10)
# Out:
#           Artist  Artist_popularity  Artist_follower               Artist_id
# 0        Ava Max                 87          1025358  4npEfmQ6YuiwW1GpUmaq3F
# 1  Billie Eilish                 98         18867904  6qqNVTkY8uBg9cP3Jd7DAH
# 2  Ariana Grande                 97         40958727  66CXWjxzNUsdJxJ2JdwvnR
# 3    Tones and I                 92           484241  2NjfBq1NflQcKSeiDooVjY
# 4   Shawn Mendes                 94         23152263  7n2wHs1TKAczGzO7Dd2rGr
# 5   Daddy Yankee                 95         15857952  4VMYDCV2IEDYJArk749S6m
# 6      Lady Gaga                 89         10181517  1HY2Jd0NmPuamShAr6KMms
# 7  Lewis Capaldi                 92          2143489  4GNC7GD6oZMSxPGyXy4MNB
# 8     Marshmello                 90         20341696  64KEffDW9EtZ1y2vBYgq8T
# 9    Post Malone                100         21335421  246dkjvS1zLTtiykXe5h60

# %%
# table of songs data with given attributes
songsDB = df[['Rank','Streams','Track Name','tempo','Artist_id']]
songsDB.head(10)
# Out:
#    Rank     Streams         Track Name    tempo               Artist_id
# 0   1.0  1166185736   Sweet but Psycho  133.002  4npEfmQ6YuiwW1GpUmaq3F
# 1   2.0  1052358787            bad guy  135.128  6qqNVTkY8uBg9cP3Jd7DAH
# 2   3.0   789094044            7 rings  140.048  66CXWjxzNUsdJxJ2JdwvnR
# 3   4.0   764208309       Dance Monkey   98.078  2NjfBq1NflQcKSeiDooVjY
# 4   5.0   763064359           Señorita  116.967  7n2wHs1TKAczGzO7Dd2rGr
# 5   6.0   715027898          Con Calma   93.989  4VMYDCV2IEDYJArk749S6m
# 6   7.0   714097238            Shallow   95.799  1HY2Jd0NmPuamShAr6KMms
# 7   8.0   661930419  Someone You Loved  109.891  4GNC7GD6oZMSxPGyXy4MNB
# 8   9.0   620829467            Happier  100.015  64KEffDW9EtZ1y2vBYgq8T
# 9  10.0   615519053               Wow.   99.947  246dkjvS1zLTtiykXe5h60

# %%
# export artist and song DBs as csv files
artistsDB.to_csv('artistsDB.csv',index=False)
songsDB.to_csv('songsDB.csv',index=False)

# %%
# numpy array of artist names
artists = artistsDB['Artist'].values

# %%
# loop to count artists, store the max count and index of artist
# in order to find the most common artist in our data

index = 0
maxCount = 0
for i in range(len(artists)):
    count = 0
    for j in range(len(artists)):
        if artists[i] == artists[j]:
            count+=1
    if count > maxCount:
        maxCount = count
        index = i

# %%
print(artists[index],'was on the list',maxCount,'times')
# Out:
# Post Malone was on the list 45 times
